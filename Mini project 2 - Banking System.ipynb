# %%
import random
s="*"
d="-"
def create():
    name = str(input("\tEnter a full name : "))
    age = int(input("\tEnter your age : "))
    gender = str(input("\tEnter your gender : "))
    add = str(input("\tEnter your address : "))
    pan = input("\tEnter Your pan card details : ")
    aadhar = int(input("\tEnter your aadhar card detaills : "))
    acc_type = str(input("\tSelect account type (saving/current) : "))
    account_no = random.randint(1001426100,1001426400)
    print(d*80)
    print()
    print("\t\tYour account is created successfully....")
    print(d*80)
    print()
    print("\t\tYour new account details are as follows :-")
    print("\t\t\tAccount holder name :-",name+"\n\t\t\tAccount holder age :-",age,"\n\t\t\tAccount Type :-",acc_type,"\n\t\t\tAccount holder account no :-",account_no)
def deposit():
    account_no = int(input("\tEnter a account no. to deposit money : "))
    amount = int(input("\tEnter a amount to deposit : "))
    balance = random.randint(120450,225000)
    print(d*80)
    print()
    print("\t\tMoney deposited successfully in account.")
    print(d*80)
    print()
    print("\t\tYour account details are as follows :-")
    print(f"\t\t\tAmount of the account before depositing money - {balance}\n\t\t\tAmount of the account after depositing money - {balance+amount}.")
def withdraw():
    account_no = int(input("\tEnter a account no. to withdraw money : "))
    amount = int(input("\tEnter a amount to withdraw : "))
    balance = random.randint(400000,625000)
    print(d*50)
    print()
    if amount < balance:
        print("\t\tMoney withdraw successfully from account please collect your cash.")
        print(d*80)
        print()
        print("\t\tYour account details are as follows :-")
        print(f"\t\t\tAmount of the account before withdrawing money - {balance}\n\t\t\tAmount of the account after withdrawing money - {balance-amount}.")
    else:
        print("\t\tNo sufficient balace available to withdraw money as per your request.")
        print(d*80)
        print()
        print(f"\t\t\tYour account balance is {balance},\n\t\t\tYou enter amount to withdraw is {amount}, which is higher than your balance.")
while True:
    print("Press 1 to create a new account.")
    print("Press 2 to deposite money to account.")
    print("Press 3 to withdraw money from account.")
    print("Press 4 to Quit.")
    print()
    ch = input("Select a operation : ")
    print(s*90)
    if ch == '1':
        create()
    elif ch == '2':
        deposit()
    elif ch == '3':
        withdraw()
    elif ch == '4':
        print()
        print("\tYou quit the method, Thank you - Visit again.")
        break
    else:
        print()
        print("\tYou select the wrong method, plese select the correct method as per menu.")
    print()
    print(s*90)
# Out:
# Press 1 to create a new account.
# Press 2 to deposite money to account.
# Press 3 to withdraw money from account.
# Press 4 to Quit.
#
# Select a operation : 1
# ******************************************************************************************
# 	Enter a full name : Ritesh Patil
# 	Enter your age : 20
# 	Enter your gender : Male
# 	Enter your address : Dombivli West
# 	Enter Your pan card details : BAUYE61729
# 	Enter your aadhar card detaills : 526381983647
# 	Select account type (saving/current) : Saving
# --------------------------------------------------------------------------------
#
# 		Your account is created successfully....
# --------------------------------------------------------------------------------
#
# 		Your new account details are as follows :-
# 			Account holder name :- Ritesh Patil
# 			Account holder age :- 20
# 			Account Type :- Saving
# 			Account holder account no :- 1001426198
#
# ******************************************************************************************
# Press 1 to create a new account.
# Press 2 to deposite money to account.
# Press 3 to withdraw money from account.
# Press 4 to Quit.
#
# Select a operation : 3
# ******************************************************************************************
# 	Enter a account no. to withdraw money : 1001426071
# 	Enter a amount to withdraw : 40000
# --------------------------------------------------
#
# 		Money withdraw successfully from account please collect your cash.
# --------------------------------------------------------------------------------
#
# 		Your account details are as follows :-
# 			Amount of the account before withdrawing money - 530454
# 			Amount of the account after withdrawing money - 490454.
#
# ******************************************************************************************
# Press 1 to create a new account.
# Press 2 to deposite money to account.
# Press 3 to withdraw money from account.
# Press 4 to Quit.
#
# Select a operation : 4
# ******************************************************************************************
#
# 	You quit the method, Thank you - Visit again.
